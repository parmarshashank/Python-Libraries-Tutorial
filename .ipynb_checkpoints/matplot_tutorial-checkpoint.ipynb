# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df= pd.read_csv("housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
plt.plot([1,2,3,4,5], [1,4,9,16,25], color='green', linestyle='--', marker='o')
plt.xlabel("numbers")
plt.ylabel("squares")
plt.show()

# %%
plt.plot([1,2,3,4,5], [1,4,9,16,25], label="squares", linestyle="--", color="blue")
plt.plot([1,2,3,4,5], [1,8,27,64,125], label="cubes", color="red")
plt.legend()
plt.grid(True)
plt.show()

# %%
f= pd.DataFrame({"Food":["meat", "banana", "avocados"], "Calories":[40, 50, 20], "fat":[8, 5, 1]})
f.head()
# Out:
#        Food  Calories  fat
# 0      meat        40    8
# 1    banana        50    5
# 2  avocados        20    1

# %%
import numpy as np 
import matplotlib.pyplot as plt 
barWidth = 0.25
IT = [12, 30, 1, 8, 22] 
ECE = [28, 6, 16, 5, 10] 
CSE = [29, 3, 24, 25, 17] 
br1 = np.arange(len(IT)) 
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2] 

plt.bar(br1, IT, color ='r', width = barWidth, 
        edgecolor ='grey', label ='IT') 
plt.bar(br2, ECE, color ='g', width = barWidth, 
        edgecolor ='grey', label ='ECE') 
plt.bar(br3, CSE, color ='b', width = barWidth, 
        edgecolor ='grey', label ='CSE')  
plt.xlabel('Branch', fontweight ='bold', fontsize = 15) 
plt.ylabel('Students passed', fontweight ='bold', fontsize = 15) 
plt.xticks([r + barWidth for r in range(len(IT))], 
        ['2015', '2016', '2017', '2018', '2019'])

plt.legend()
plt.show()

# %%
data = {
    'Food': ['Apple', 'Banana', 'Orange', 'Strawberry', 'Blueberry'],
    'Calories': [95, 105, 62, 4, 84],
    'Fat': [3, 4, 23, 12, 32]
}
f = pd.DataFrame(data)
bar_width=0.35
b1=np.arange(len(f.Calories))
b2=[x+bar_width for x in b1]
plt.bar(b1, f.Calories, label="Calories", color="blue", width=bar_width)
plt.bar(b2, f.Fat, label="Fat", color="red", width=bar_width)
plt.legend()
plt.xticks([x+bar_width for x in range(5)], f.Food)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 35]
plt.plot(x, y)
plt.xticks([1, 2, 3, 4, 5])
plt.show()

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
df.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
plt.hist(df.ocean_proximity, bins=50, color="yellow")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data1 = np.random.randn(1000)
data2 = np.random.randn(1000) + 2  
plt.hist(data1, bins=30, alpha=0.5, label='Data 1', color='blue', edgecolor='black')
plt.hist(data2, bins=30, alpha=0.5, label='Data 2', color='red', edgecolor='black')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Multiple Histograms')
plt.legend()

plt.show()

# %%
df.loc[:,['median_income', 'median_house_value']]
# Out:
#        median_income  median_house_value
# 0             8.3252            452600.0
# 1             8.3014            358500.0
# 2             7.2574            352100.0
# 3             5.6431            341300.0
# 4             3.8462            342200.0
# ...              ...                 ...
# 20635         1.5603             78100.0
# 20636         2.5568             77100.0
# 20637         1.7000             92300.0
# 20638         1.8672             84700.0
# 20639         2.3886             89400.0
#
# [20640 rows x 2 columns]

# %%
plt.scatter(df.median_income, df.median_house_value)

# %%
data = {
    'X': [1, 2, 3, 4, 5],
    'Y': [2, 3, 5, 7, 11],
    'Size': [100, 200, 300, 400, 500],
    'Color': [10, 20, 30, 40, 50]
}
df = pd.DataFrame(data)

plt.scatter('X', 'Y', s='Size', c='Color', alpha=0.5, data=df)

plt.colorbar()

plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Scatter Plot from DataFrame')

plt.show()

# %%
labels = ['Apples', 'Bananas', 'Cherries', 'Dates']
sizes = [15, 30, 45, 10]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']

plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=0)
plt.title('Fruit Distribution with Custom Colors')
plt.show()

# %%
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
plt.fill_between(x, y1, color="gray", alpha=0.4)
plt.fill_between(x, y2, color="black", alpha=0.5)
plt.title("Area Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()
